# %%
import pandas as pd
import ijson

# %%
filename = "data.json"

# %%
df1 = pd.read_json(filename)

# %%
df1.head()
# Out:
#                                              address  \
# 0  Neuköllner Straße 1\r\n52068 Aachen\r\n\r\nPos...
# 1                Neuköllner Straße 1\r\n52068 Aachen
# 2               Sonnenstraße 22\r\n27568 Bremerhaven
# 3
# 4  Hauptadresse\nGodesberger Allee 142 - 148\n531...
#
#                                           categories  \
# 0  [{'id': 10, 'name': 'Verkehr', 'slug': 'verkeh...
# 1                                                 []
# 2  [{'id': 197, 'name': 'Schule', 'slug': 'schule...
# 3  [{'id': 227, 'name': 'Legislative', 'slug': 'l...
# 4  [{'id': 2, 'name': 'Landwirtschaft', 'slug': '...
#
#                                       classification  \
# 0  {'id': 54, 'name': 'Verkehrsbetriebe', 'slug':...
# 1  {'id': 582, 'name': 'Verkehr', 'slug': 'verkeh...
# 2  {'id': 546, 'name': 'Abendschule', 'slug': 'ab...
# 3  {'id': 521, 'name': 'Landtagsverwaltung', 'slu...
# 4  {'id': 594, 'name': 'Wirtschaftsförderung', 's...
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13496 entries, 0 to 13495
# Data columns (total 22 columns):
# address               13496 non-null object
# categories            13496 non-null object
# classification        11856 non-null object
# contact               13496 non-null object
# depth                 13496 non-null int64
# description           13496 non-null object
# email                 13496 non-null object
# id                    13496 non-null int64
# jurisdiction          13496 non-null object
# laws                  13496 non-null object
# name                  13496 non-null object
# number_of_requests    13496 non-null int64
# other_names           13496 non-null object
# parent                1184 non-null object
# regions               13496 non-null object
# request_note          13496 non-null object
# request_note_html     13496 non-null object
# resource_uri          13496 non-null object
# root                  519 non-null object
# ...

# %%
list(df1)
# Out:
# ['address',
#  'categories',
#  'classification',
#  'contact',
#  'depth',
#  'description',
#  'email',
#  'id',
#  'jurisdiction',
#  'laws',
#  'name',
#  'number_of_requests',
#  'other_names',
#  'parent',
#  'regions',
#  'request_note',
#  'request_note_html',
#  'resource_uri',
#  'root',
#  'site_url',
#  'slug',
#  'url']

# %%
df2 = df1.drop(["address", "contact", "depth", "description", "email", "url"], axis=1)

# %%
df3 = df2.set_index("slug")

# %%
df3.head()
# Out:
#                                                                                            categories  \
# slug
# aachen-verkehr                                      [{'id': 10, 'name': 'Verkehr', 'slug': 'verkeh...
# aachener-verkehrsverbund-gmbh                                                                      []
# abendschule-bremerhaven                             [{'id': 197, 'name': 'Schule', 'slug': 'schule...
# abgeordnetenhaus-von-berlin                         [{'id': 227, 'name': 'Legislative', 'slug': 'l...
# absatzforderungsfonds-der-deutschen-forst-und-h...  [{'id': 2, 'name': 'Landwirtschaft', 'slug': '...
#
#                                                                                        classification  \
# slug
# aachen-verkehr                                      {'id': 54, 'name': 'Verkehrsbetriebe', 'slug':...
# aachener-verkehrsverbund-gmbh                       {'id': 582, 'name': 'Verkehr', 'slug': 'verkeh...
# ...

# %%
# meiste anfragen an:
most = df3.sort_values(["number_of_requests"], ascending=False)
most.head(10)
# Out:
#                                                                                            categories  \
# slug
# bundesinstitut-fur-risikobewertung                  [{'id': 2, 'name': 'Landwirtschaft', 'slug': '...
# deutscher-bundestag                                 [{'id': 188, 'name': 'Zentrale Verwaltung', 's...
# bundesamt-fur-sicherheit-in-der-informationstec...  [{'id': 7, 'name': 'Inneres', 'slug': 'inneres...
# bundesministerium-des-innern                        [{'id': 7, 'name': 'Inneres', 'slug': 'inneres...
# bundeskanzleramt                                    [{'id': 7, 'name': 'Inneres', 'slug': 'inneres...
# ministerium-fur-schule-und-weiterbildung-des-la...  [{'id': 185, 'name': 'Bildung', 'slug': 'bildu...
# ministerium-fur-energiewende-landwirtschaft-umw...  [{'id': 187, 'name': 'Energie', 'slug': 'energ...
# bundesministerium-der-justiz                        [{'id': 1, 'name': 'Justiz', 'slug': 'justiz',...
# ...
