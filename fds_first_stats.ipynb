# %%
import pandas as pd

publicbody = pd.read_csv("publicbody.csv", index_col="id")
requests = pd.read_csv("requests.csv", index_col="id", low_memory=False)

# %%
publicbody.head()
# Out:
#                                                     slug      categories  \
# id
# 15131                                     aachen-verkehr         verkehr
# 16137                      aachener-verkehrsverbund-gmbh           keine
# 6614                             abendschule-bremerhaven          schule
# 3780                         abgeordnetenhaus-von-berlin     legislative
# 2      absatzforderungsfonds-der-deutschen-forst-und-...  landwirtschaft
#
#              classification  \
# id
# 15131      verkehrsbetriebe
# 16137               verkehr
# 6614            abendschule
# 3780     landtagsverwaltung
# 2      wirtschaftsforderung
#
#                                                     name  number_of_requests  \
# id
# 15131     Aachener Straßenbahn und Energieversorgungs-AG                   3
# 16137                      Aachener Verkehrsverbund GmbH                   0
# 6614                             Abendschule Bremerhaven                   0
# 3780                         Abgeordnetenhaus von Berlin                  30
# 2      Absatzförderungsfonds der deutschen Forst- und...                   2
#
#                          other_names  \
# id
# 15131                            NaN
# 16137  AVV, Aachener Verkehrsverbund
# 6614                             NaN
# 3780                             agh
# 2                                NaN
#
#                                               parent regions request_note  \
# id
# 15131                                            NaN      []          NaN
# 16137                                            NaN      []          NaN
# 6614                                             NaN      []          NaN
# 3780                                             NaN      []          NaN
# 2      https://fragdenstaat.de/api/v1/publicbody/90/      []          NaN
#
#       request_note_html                                      resource_uri  \
# id
# 15131               NaN  https://fragdenstaat.de/api/v1/publicbody/15131/
# 16137               NaN  https://fragdenstaat.de/api/v1/publicbody/16137/
# 6614                NaN   https://fragdenstaat.de/api/v1/publicbody/6614/
# 3780                NaN   https://fragdenstaat.de/api/v1/publicbody/3780/
# 2                   NaN      https://fragdenstaat.de/api/v1/publicbody/2/
#
#                                                 root  \
# id
# 15131                                            NaN
# 16137                                            NaN
# 6614                                             NaN
# 3780                                             NaN
# 2      https://fragdenstaat.de/api/v1/publicbody/90/
#
#                                                 site_url bundesland  \
# id
# 15131   https://fragdenstaat.de/behoerde/aachen-verkehr/        nrw
# 16137  https://fragdenstaat.de/behoerde/aachener-verk...        nrw
# 6614   https://fragdenstaat.de/behoerde/abendschule-b...     bremen
# 3780   https://fragdenstaat.de/behoerde/abgeordnetenh...     berlin
# 2      https://fragdenstaat.de/behoerde/absatzforderu...       bund
#
#        bundesland_id                                        region
# id
# 15131              2   https://fragdenstaat.de/api/v1/georegion/6/
# 16137              2   https://fragdenstaat.de/api/v1/georegion/6/
# 6614              12   https://fragdenstaat.de/api/v1/georegion/5/
# 3780               4  https://fragdenstaat.de/api/v1/georegion/12/
# 2                  1   https://fragdenstaat.de/api/v1/georegion/1/

# %%
publicbody.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13496 entries, 15131 to 4108
# Data columns (total 16 columns):
# slug                  13496 non-null object
# categories            13496 non-null object
# classification        13496 non-null object
# name                  13496 non-null object
# number_of_requests    13496 non-null int64
# other_names           1594 non-null object
# parent                1184 non-null object
# regions               13496 non-null object
# request_note          67 non-null object
# request_note_html     67 non-null object
# resource_uri          13496 non-null object
# root                  519 non-null object
# site_url              13496 non-null object
# bundesland            13496 non-null object
# bundesland_id         13496 non-null int64
# region                13247 non-null object
# dtypes: int64(2), object(14)
# memory usage: 1.8+ MB

# %%
requests.head()
# Out:
#                                                      slug  costs  \
# id
# 136323  stellungnahme-des-bfr-zur-iarc-monographie-ube...    0.0
# 136322  stellungnahme-des-bfr-zur-iarc-monographie-ube...    0.0
# 41839               kontrollbericht-zu-jagerheim-dortmund    0.0
# 136192           transparency-unit-staffing-and-budget-48    0.0
# 136321  stellungnahme-des-bfr-zur-iarc-monographie-ube...    0.0
#
#                                               description  \
# id
# 136323  Die Stellungnahme des BfR zur IARC- Monographi...
# 136322  Die Stellungnahme des BfR zur IARC- Monographi...
# 41839   1. Wann haben die beiden letzten lebensmittelr...
# 136192  Dear Sir or Madam,\r\r\n\r\r\nUnder the right ...
# 136321  Die Stellungnahme des BfR zur IARC- Monographi...
#
#                                 due_date                     first_message  \
# id
# 136323         2019-06-05T00:00:00+02:00  2019-05-03T19:24:19.557867+02:00
# 136322         2019-06-05T00:00:00+02:00  2019-05-03T19:12:37.012030+02:00
# 41839          2019-03-19T00:00:00+01:00  2019-01-15T15:54:57.209913+01:00
# 136192  2019-05-24T12:06:32.539072+02:00  2019-05-03T12:06:32.532525+02:00
# 136321         2019-06-05T00:00:00+02:00  2019-05-03T18:47:58.434255+02:00
#
#                             last_message  public  \
# id
# 136323  2019-05-03T19:24:19.557867+02:00    True
# 136322         2019-05-03T19:22:48+02:00    True
# 41839   2019-05-03T19:13:20.609343+02:00    True
# 136192         2019-05-03T19:09:52+02:00    True
# 136321         2019-05-03T19:07:44+02:00    True
#
#                                               public_body  \
# id
# 136323  {'resource_uri': 'https://fragdenstaat.de/api/...
# 136322  {'resource_uri': 'https://fragdenstaat.de/api/...
# 41839   {'resource_uri': 'https://fragdenstaat.de/api/...
# 136192  {'resource_uri': 'https://fragdenstaat.de/api/...
# 136321  {'resource_uri': 'https://fragdenstaat.de/api/...
#
#                            reference refusal_reason resolution resolved_on  \
# id
# 136323                    glyphosat:            NaN        NaN         NaN
# 136322                    glyphosat:            NaN        NaN         NaN
# 41839   food:amenity:19094_301808705            NaN        NaN         NaN
# 136192                           NaN            NaN        NaN         NaN
# 136321                    glyphosat:            NaN        NaN         NaN
#
#                                               same_as  \
# id
# 136323  https://fragdenstaat.de/api/v1/request/63147/
# 136322  https://fragdenstaat.de/api/v1/request/63147/
# 41839                                             NaN
# 136192                                            NaN
# 136321  https://fragdenstaat.de/api/v1/request/63147/
#
#                          status  \
# id
# 136323        awaiting_response
# 136322  awaiting_classification
# 41839         awaiting_response
# 136192  awaiting_classification
# 136321  awaiting_classification
#
#                                                       url public_body_id  \
# id
# 136323  /anfrage/stellungnahme-des-bfr-zur-iarc-monogr...             69
# 136322  /anfrage/stellungnahme-des-bfr-zur-iarc-monogr...             69
# 41839     /anfrage/kontrollbericht-zu-jagerheim-dortmund/          15586
# 136192  /anfrage/transparency-unit-staffing-and-budget...          16048
# 136321  /anfrage/stellungnahme-des-bfr-zur-iarc-monogr...             69
#
#                                 public_body_slug
# id
# 136323        bundesinstitut-fur-risikobewertung
# 136322        bundesinstitut-fur-risikobewertung
# 41839                 stadt-dortmund-ordnungsamt
# 136192  europaeische-stiftung-fuer-berufsbildung
# 136321        bundesinstitut-fur-risikobewertung

# %%
requests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96244 entries, 136323 to 191
# Data columns (total 17 columns):
# slug                96244 non-null object
# costs               96244 non-null float64
# description         96237 non-null object
# due_date            95826 non-null object
# first_message       96244 non-null object
# last_message        96244 non-null object
# public              96244 non-null bool
# public_body         95868 non-null object
# reference           35581 non-null object
# refusal_reason      1468 non-null object
# resolution          29064 non-null object
# resolved_on         4 non-null object
# same_as             42564 non-null object
# status              96244 non-null object
# url                 96244 non-null object
# public_body_id      96244 non-null object
# public_body_slug    96244 non-null object
# dtypes: bool(1), float64(1), object(15)
# memory usage: 12.6+ MB

# %% [markdown]
# # AVERAGE COSTS

# %%
requests['costs'].describe()
# Out:
# count    96244.000000
# mean         3.535361
# std        124.791362
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      30000.000000
# Name: costs, dtype: float64

# %%
costs_per_body = requests.groupby('public_body_slug')['costs'].sum() # costs of each public body
type(costs_per_body)
# Out:
# pandas.core.series.Series

# %%
requests_per_body = requests.groupby('public_body_slug').count() # number of requests per amt, e.g. "slug" (ist immer ausgefüllt)
# achtung: stimmt nicht mit "publicbody" überein! (abgeordnetenhaus-von-berlin -> 30 vs. 27)

requests_per_body = requests_per_body["costs"]
type(requests_per_body)
# Out:
# pandas.core.series.Series

# %%
new_df = pd.concat([costs_per_body, requests_per_body], axis=1)
new_df.columns = ['total_costs', 'total_requests']

# %%
# now create new column: average costs (total_costs/total_requests)
new_df["average_costs"] = new_df["total_costs"] / new_df["total_requests"]
new_df.head()
# Out:
#                                                     total_costs  \
# public_body_slug
# -landratsamt-rems-murr-kreis-veterinaramt-und-l...       1000.0
# aachen-verkehr                                              0.0
# abgeordnetenhaus-von-berlin                                 0.0
# absatzforderungsfonds-der-deutschen-forst-und-h...          0.0
# absatzforderungsfonds-der-deutschen-land-und-er...          0.0
#
#                                                     total_requests  \
# public_body_slug
# -landratsamt-rems-murr-kreis-veterinaramt-und-l...              96
# aachen-verkehr                                                   2
# abgeordnetenhaus-von-berlin                                     27
# absatzforderungsfonds-der-deutschen-forst-und-h...               2
# absatzforderungsfonds-der-deutschen-land-und-er...               1
#
#                                                     average_costs
# public_body_slug
# -landratsamt-rems-murr-kreis-veterinaramt-und-l...      10.416667
# aachen-verkehr                                           0.000000
# abgeordnetenhaus-von-berlin                              0.000000
# absatzforderungsfonds-der-deutschen-forst-und-h...       0.000000
# absatzforderungsfonds-der-deutschen-land-und-er...       0.000000

# %%
new_df_final = new_df.sort_values('average_costs', ascending=False) #!!!
new_df_final
# Out:
#                                                     total_costs  \
# public_body_slug
# landratsamt-ostalbkreis                                 2400.00
# schulamt-fur-die-stadt-bielefeld                       13000.00
# verbandsgemeindeverwaltung-bitburg-land                  820.00
# ministerium-fur-landwirtschaft-umwelt-und-verbr...      5000.00
# staatsarchiv-munchen                                     696.00
# amt-fur-verbraucherschutz-und-landwirtschaft-la...      2000.00
# vertretung-der-freien-und-hansestadt-hamburg-be...       500.00
# universitatsklinikum-magdeburg-or                        500.00
# kommunalverwaltung-nottuln                              1000.00
# medienanstalt-hamburg-schleswig-holstein-ma-hsh          500.00
# stadt-und-uberlandwerke-gmbh-lubben-suw                 2000.00
# stadtordnungsdienst-ordnungsamt                        254.320000
# jobcenter-furth-land                                   251.666667
# universitatsbibliothek-freiburgbreisgau                250.000000
# tiefbauamt-berlin-tempelhof-schoneberg                 250.000000
# untere-jagdbehorde-essen                               250.000000
# kommunalverwaltung-erkrath                             236.875000
# landkreis-wolfenbuttel-verbraucherschutz-und-ve...     234.100000
# ...                                                           ...
# jobcenter-furth-stadt                                    0.000000
# jobcenter-duisburg                                       0.000000
# jobcenter-dortmund                                       0.000000
# jobcenter-boblingen                                      0.000000
# jobcenter-charlottenburg-wilmersdorf                     0.000000
# jobcenter-bochum                                         0.000000
# jobcenter-bodenseekreis                                  0.000000
# jobcenter-bonn                                           0.000000
# jobcenter-borde                                          0.000000
# jobcenter-bottrop                                        0.000000
# jobcenter-brandenburg-an-der-havel                       0.000000
# jobcenter-braunschweig                                   0.000000
# jobcenter-breisgau-hochschwarzwald                       0.000000
# jobcenter-bremen                                         0.000000
# jobcenter-bremerhaven                                    0.000000
# jobcenter-burgenlandkreis                                0.000000
# jobcenter-cloppenburg                                    0.000000
# jobcenter-donnersbergkreis                               0.000000
# jobcenter-coburg-stadt                                   0.000000
# jobcenter-cochem-zell                                    0.000000
# jobcenter-cottbus                                        0.000000
# jobcenter-cuxhaven                                       0.000000
# jobcenter-darmstadt                                      0.000000
# jobcenter-deggendorf                                     0.000000
# jobcenter-delmenhorst                                    0.000000
# jobcenter-dessau-rolau                                   0.000000
# jobcenter-dillingen-ad-donau                             0.000000
# jobcenter-dithmarschen-heide                             0.000000
# jobcenter-donau-ries-donauworth                          0.000000
# zweites-deutsches-fernsehen                              0.000000
#
# [3839 rows x 3 columns]

# %%
# select relevant data
plot_data = new_df_final["average_costs"].head(20)
plot_data.plot(kind="bar")
plt.title("Average Costs of a Request to the Most Expensive Public Bodies")
# Out:
# Text(0.5,1,'Average Costs of a Request to the Most Expensive Public Bodies')

# %% [markdown]
# # EXPENSIVE BUNDESLÄNDER

# %%
pb = publicbody.set_index("slug")
pb.head()
# Out:
#                                                         categories  \
# slug
# aachen-verkehr                                             verkehr
# aachener-verkehrsverbund-gmbh                                keine
# abendschule-bremerhaven                                     schule
# abgeordnetenhaus-von-berlin                            legislative
# absatzforderungsfonds-der-deutschen-forst-und-h...  landwirtschaft
#
#                                                           classification  \
# slug
# aachen-verkehr                                          verkehrsbetriebe
# aachener-verkehrsverbund-gmbh                                    verkehr
# abendschule-bremerhaven                                      abendschule
# abgeordnetenhaus-von-berlin                           landtagsverwaltung
# absatzforderungsfonds-der-deutschen-forst-und-h...  wirtschaftsforderung
#
#                                                                                                  name  \
# slug
# aachen-verkehr                                         Aachener Straßenbahn und Energieversorgungs-AG
# aachener-verkehrsverbund-gmbh                                           Aachener Verkehrsverbund GmbH
# abendschule-bremerhaven                                                       Abendschule Bremerhaven
# abgeordnetenhaus-von-berlin                                               Abgeordnetenhaus von Berlin
# absatzforderungsfonds-der-deutschen-forst-und-h...  Absatzförderungsfonds der deutschen Forst- und...
#
#                                                     number_of_requests  \
# slug
# aachen-verkehr                                                       3
# aachener-verkehrsverbund-gmbh                                        0
# abendschule-bremerhaven                                              0
# abgeordnetenhaus-von-berlin                                         30
# absatzforderungsfonds-der-deutschen-forst-und-h...                   2
#
#                                                                       other_names  \
# slug
# aachen-verkehr                                                                NaN
# aachener-verkehrsverbund-gmbh                       AVV, Aachener Verkehrsverbund
# abendschule-bremerhaven                                                       NaN
# abgeordnetenhaus-von-berlin                                                   agh
# absatzforderungsfonds-der-deutschen-forst-und-h...                            NaN
#
#                                                                                            parent  \
# slug
# aachen-verkehr                                                                                NaN
# aachener-verkehrsverbund-gmbh                                                                 NaN
# abendschule-bremerhaven                                                                       NaN
# abgeordnetenhaus-von-berlin                                                                   NaN
# absatzforderungsfonds-der-deutschen-forst-und-h...  https://fragdenstaat.de/api/v1/publicbody/90/
#
#                                                    regions request_note  \
# slug
# aachen-verkehr                                          []          NaN
# aachener-verkehrsverbund-gmbh                           []          NaN
# abendschule-bremerhaven                                 []          NaN
# abgeordnetenhaus-von-berlin                             []          NaN
# absatzforderungsfonds-der-deutschen-forst-und-h...      []          NaN
#
#                                                    request_note_html  \
# slug
# aachen-verkehr                                                   NaN
# aachener-verkehrsverbund-gmbh                                    NaN
# abendschule-bremerhaven                                          NaN
# abgeordnetenhaus-von-berlin                                      NaN
# absatzforderungsfonds-der-deutschen-forst-und-h...               NaN
#
#                                                                                         resource_uri  \
# slug
# aachen-verkehr                                      https://fragdenstaat.de/api/v1/publicbody/15131/
# aachener-verkehrsverbund-gmbh                       https://fragdenstaat.de/api/v1/publicbody/16137/
# abendschule-bremerhaven                              https://fragdenstaat.de/api/v1/publicbody/6614/
# abgeordnetenhaus-von-berlin                          https://fragdenstaat.de/api/v1/publicbody/3780/
# absatzforderungsfonds-der-deutschen-forst-und-h...      https://fragdenstaat.de/api/v1/publicbody/2/
#
#                                                                                              root  \
# slug
# aachen-verkehr                                                                                NaN
# aachener-verkehrsverbund-gmbh                                                                 NaN
# abendschule-bremerhaven                                                                       NaN
# abgeordnetenhaus-von-berlin                                                                   NaN
# absatzforderungsfonds-der-deutschen-forst-und-h...  https://fragdenstaat.de/api/v1/publicbody/90/
#
#                                                                                              site_url  \
# slug
# aachen-verkehr                                       https://fragdenstaat.de/behoerde/aachen-verkehr/
# aachener-verkehrsverbund-gmbh                       https://fragdenstaat.de/behoerde/aachener-verk...
# abendschule-bremerhaven                             https://fragdenstaat.de/behoerde/abendschule-b...
# abgeordnetenhaus-von-berlin                         https://fragdenstaat.de/behoerde/abgeordnetenh...
# absatzforderungsfonds-der-deutschen-forst-und-h...  https://fragdenstaat.de/behoerde/absatzforderu...
#
#                                                    bundesland  bundesland_id  \
# slug
# aachen-verkehr                                            nrw              2
# aachener-verkehrsverbund-gmbh                             nrw              2
# abendschule-bremerhaven                                bremen             12
# abgeordnetenhaus-von-berlin                            berlin              4
# absatzforderungsfonds-der-deutschen-forst-und-h...       bund              1
#
#                                                                                           region
# slug
# aachen-verkehr                                       https://fragdenstaat.de/api/v1/georegion/6/
# aachener-verkehrsverbund-gmbh                        https://fragdenstaat.de/api/v1/georegion/6/
# zweckverband-fur-kommunale-verkehrssicherheit-oberpfalz                                                          bayern
# zweckverband-fur-rettungsdienst-und-feuerwehralarmierung-saar-zrf                                              saarland
# zweckverband-gesundheitsamt-luchow-dannenberg                                                             niedersachsen
# zweckverband-gesundheitsamt-uelzen                                                                        niedersachsen
# zweckverband-komplexsanierung-mittlerer-suden                                                               brandenburg
# zweckverband-nahverkehr-spnv-infrastruktur-rheinland                                                                nrw
# zweckverband-nahverkehr-westfalen-lippe-nwl                                                                         nrw
# zweckverband-rbb-restmullheizkraftwerk-boblingen                                                      baden-wurttemberg
# zweckverband-sachsisches-industriemuseum                                                                        sachsen
# zweckverband-schienenpersonennahverkehr-rheinland-pfalz-sud                                             rheinland-pfalz
# zweckverband-schulen-muenchen                                                                                   munchen
# zweckverband-verwertung-grunabfalle-ensdorf                                                                    saarland
# zweckverband-wasserversorgung-und-abwasserentsorgung-ostharz                                             sachsen-anhalt
# zweites-deutsches-fernsehen                                                                                        bund
# Name: bundesland, Length: 13496, dtype: object

# %%
w_bl = new_df
w_bl["average_costs"] = w_bl["total_costs"] / w_bl["total_requests"]
w_bl = pd.concat([w_bl, pb], axis=1, sort=True)
w_bl.head()
# Out:
#                                                     total_costs  \
# -landratsamt-rems-murr-kreis-veterinaramt-und-l...       1000.0
# aachen-verkehr                                              0.0
# aachener-verkehrsverbund-gmbh                               NaN
# abendschule-bremerhaven                                     NaN
# abgeordnetenhaus-von-berlin                                 0.0
#
#                                                     total_requests  \
# -landratsamt-rems-murr-kreis-veterinaramt-und-l...            96.0
# aachen-verkehr                                                 2.0
# aachener-verkehrsverbund-gmbh                                  NaN
# abendschule-bremerhaven                                        NaN
# abgeordnetenhaus-von-berlin                                   27.0
#
#                                                     average_costs  \
# -landratsamt-rems-murr-kreis-veterinaramt-und-l...      10.416667
# aachen-verkehr                                           0.000000
# aachener-verkehrsverbund-gmbh                                 NaN
# abendschule-bremerhaven                                       NaN
# abgeordnetenhaus-von-berlin                              0.000000
#
#                                                            bundesland
# -landratsamt-rems-murr-kreis-veterinaramt-und-l...  baden-wurttemberg
# aachen-verkehr                                                    nrw
# aachener-verkehrsverbund-gmbh                                     nrw
# abendschule-bremerhaven                                        bremen
# abgeordnetenhaus-von-berlin                                    berlin

# %%
w_bl.sort_values('average_costs', ascending=False).head()
# Out:
#                                                     total_costs  \
# landratsamt-ostalbkreis                                  2400.0
# schulamt-fur-die-stadt-bielefeld                        13000.0
# verbandsgemeindeverwaltung-bitburg-land                   820.0
# ministerium-fur-landwirtschaft-umwelt-und-verbr...       5000.0
# staatsarchiv-munchen                                      696.0
#
#                                                     total_requests  \
# landratsamt-ostalbkreis                                        2.0
# schulamt-fur-die-stadt-bielefeld                              14.0
# verbandsgemeindeverwaltung-bitburg-land                        1.0
# ministerium-fur-landwirtschaft-umwelt-und-verbr...             7.0
# staatsarchiv-munchen                                           1.0
#
#                                                     average_costs  \
# landratsamt-ostalbkreis                               1200.000000
# schulamt-fur-die-stadt-bielefeld                       928.571429
# verbandsgemeindeverwaltung-bitburg-land                820.000000
# ministerium-fur-landwirtschaft-umwelt-und-verbr...     714.285714
# staatsarchiv-munchen                                   696.000000
#
#                                                                 bundesland
# landratsamt-ostalbkreis                                  baden-wurttemberg
# schulamt-fur-die-stadt-bielefeld                                       nrw
# verbandsgemeindeverwaltung-bitburg-land                    rheinland-pfalz
# ministerium-fur-landwirtschaft-umwelt-und-verbr...  mecklenburg-vorpommern
# staatsarchiv-munchen                                                bayern

# %%
# now calculate average costs per bundesland:
bl = w_bl.groupby("bundesland").sum()
bl = bl.sort_values("total_requests", ascending=False)
bl = bl.drop("average_costs", axis=1)
bl.head()
# Out:
#                    total_costs  total_requests
# bundesland
# bund                81177.4700         56672.0
# nrw                 55728.0801          8680.0
# bayern               3118.5000          4546.0
# baden-wurttemberg   49290.3800          4300.0
# berlin              43228.0400          3412.0

# %%
bl["average_costs"] = bl["total_costs"] / bl["total_requests"]
bl = bl.sort_values("average_costs", ascending=False)
bl.head(30) # !!!!!!
# Out:
#                         total_costs  total_requests  average_costs
# bundesland
# mecklenburg-vorpommern   10411.8500           660.0      15.775530
# berlin                   43228.0400          3412.0      12.669414
# hamburg                  30779.8800          2530.0      12.165960
# bamberg                    115.0000            10.0      11.500000
# baden-wurttemberg        49290.3800          4300.0      11.462879
# sachsen-anhalt            7721.2800           708.0      10.905763
# bremen                    7295.4500           678.0      10.760251
# niedersachsen            19878.6000          2567.0       7.743903
# brandenburg              11006.5000          1427.0       7.713034
# ingolstadt                  97.5000            13.0       7.500000
# nrw                      55728.0801          8680.0       6.420286
# thueringen                4550.1800           763.0       5.963539
# rheinland-pfalz           6879.5100          2197.0       3.131320
# munchen                    285.0000           112.0       2.544643
# saarland                   996.0000           484.0       2.057851
# schleswig-holstein        2551.0000          1634.0       1.561200
# bund                     81177.4700         56672.0       1.432409
# hessen                    2195.7000          2852.0       0.769881
# bayern                    3118.5000          4546.0       0.685988
# sachsen                    351.4000           964.0       0.364523
# augsburg                     0.0000            17.0       0.000000
# passau                       0.0000            15.0       0.000000
# nurnberg                     0.0000            15.0       0.000000
# altdorf                      0.0000             3.0       0.000000
# leipzig                      0.0000            14.0       0.000000
# furth                        0.0000            10.0       0.000000
# oberbayern                   0.0000             7.0       0.000000
# wurzburg                     0.0000             7.0       0.000000
# regensburg                   0.0000             5.0       0.000000
# bayreuth                     0.0000             3.0       0.000000

# %%
import matplotlib.pyplot as plt

# %%
# select relevant data
plot_data = bl["average_costs"].head(20)
plot_data.plot(kind="bar")
plt.title("Average Expenses per Request")
# Out:
# Text(0.5,1,'Average Expenses per Request')

# %% [markdown]
# # Bundesland, an das die meisten Anfragen gestellt wurden:

# %%
most_req = bl.sort_values("total_requests", ascending=False)
plot_data = most_req["total_requests"].head(20)

plot_data.plot(kind="bar")
plt.title("Highest Numbers of Requests to a Verwaltungseinheit")
# Out:
# Text(0.5,1,'Highest Numbers of Requests to a Verwaltungseinheit')

# %% [markdown]
# # IDEEN
# - meiste anfragen (bundesland) CHECK
# - behörde mit meisten anfragen CHECK
# - behörde + bundesland mit längster Bearbeitungszeit (first message -> last message if status == erledigt) --> dateutil library
# - behörde + bundesland mit höchsten kosten CHECK
# - behörde + bundesland mit meisten offenen anfragen
# - arbeitsbereiche mit längster bearbeitungszeit etc. (publicbody: category, classification)
